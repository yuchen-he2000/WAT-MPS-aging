# %%
import numpy as np
import pandas as pd

# %%
# Read in normalized data

Normalized_counts_save_dir = '/Volumes/Elements/20240213_Serum_Change_RNAseq_novogene/Results_Yuchen/1_Normalized_Counts/'
df = pd.read_excel(Normalized_counts_save_dir + '1_Median_of_Ratios_normalized_counts_All_sample.xlsx')
df
# Out:
#                gene_id         Ctrl1         Ctrl2         Ctrl3  \
# 0      ENSG00000087086  1.220955e+06  1.141922e+06  1.031176e+06
# 1      ENSG00000099194  9.544785e+05  7.815641e+05  5.275813e+05
# 2      ENSG00000170323  5.002016e+05  4.500698e+05  3.202915e+05
# 3      ENSG00000211445  3.232648e+05  2.100729e+05  2.740406e+05
# 4      ENSG00000210082  1.583665e+05  1.341154e+05  8.039464e+04
# ...                ...           ...           ...           ...
# 58730  ENSG00000276351  0.000000e+00  0.000000e+00  0.000000e+00
# 58731  ENSG00000275661  0.000000e+00  0.000000e+00  0.000000e+00
# 58732  ENSG00000277856  0.000000e+00  0.000000e+00  0.000000e+00
# 58733  ENSG00000275063  0.000000e+00  0.000000e+00  0.000000e+00
# 58734  ENSG00000268674  0.000000e+00  0.000000e+00  0.000000e+00
#
#                 YY1            YY2           YY3           YO1           YO2  \
# 0      1.403261e+06  884835.330174  1.211055e+06  1.827006e+06  9.833186e+05
# 1      1.004424e+06  848590.019893  3.983516e+05  1.416364e+06  1.199529e+06
# 2      5.480002e+05  428715.058482  5.513297e+05  5.672242e+05  4.237947e+05
# 3      2.414436e+05  221571.468104  2.529012e+05  2.845052e+05  2.391682e+05
# 4      2.713054e+05  204525.316013  1.351906e+05  2.888645e+05  2.207179e+05
# ...             ...            ...           ...           ...           ...
# 58730  0.000000e+00       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 58731  0.000000e+00       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 58732  0.000000e+00       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 58733  0.000000e+00       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
# 58734  0.000000e+00       0.000000  0.000000e+00  0.000000e+00  0.000000e+00
#
#                  YO3            OY1            OY2            OY3  \
# 0      851478.416221  678235.091780  575153.696013  687657.385389
# 1      591526.656461  333575.700563  180844.447648  249559.360952
# 2      417881.515396  525151.864808  301734.827226  383507.939518
# 3      183249.175677  100343.833975  130881.106063  141155.676642
# 4      173293.278829  166333.209290  125575.858770  154004.678682
# ...              ...            ...            ...            ...
# 58730       0.000000       0.000000       0.000000       0.000000
# 58731       0.000000       0.000000       0.000000       0.000000
# 58732       0.000000       0.000000       0.000000       0.000000
# 58733       0.000000       0.000000       0.000000       0.000000
# 58734       0.000000       0.000000       0.000000       0.000000
#
#                  OO1            OO2            OO3          OY3_1
# 0      602736.162799  652354.523499  866590.445087  604713.349135
# 1      281529.204936  168654.568907   73628.414438   79640.405055
# 2      375692.733019  315057.598385  200304.817939  207715.205749
# 3      115062.603320  152267.004362  225834.735534  209562.849613
# 4      135232.698791  106722.088248   81151.049537   62433.634196
# ...              ...            ...            ...            ...
# 58730       0.000000       0.000000       0.000000       0.000000
# 58731       0.000000       0.000000       0.000000       0.000000
# 58732       0.000000       0.000000       0.000000       0.000000
# 58733       0.000000       0.000000       0.000000       0.000000
# 58734       0.000000       0.000000       0.000000       0.000000
#
# [58735 rows x 17 columns]

# %%
# re-format the dataframes to put gene_name as rownames (indexes)

def NameRows_Gene(df):
# YO2            Het_YO
# YO3            Het_YO
# OY1            Het_OY
# OY2            Het_OY
# OY3            Het_OY
# OO1           Iso_Old
# OO2           Iso_Old
# OO3           Iso_Old
# OY3_1          Het_OY

# %%
# check whether gene_id is unique before proceeding to further analysis

duplicated_columns = df.columns[df.columns.duplicated()].unique()
print("Duplicated column names:", duplicated_columns)
# Out:
# Duplicated column names: Index([], dtype='object')

# %%
gene_info_df = pd.read_excel(Normalized_counts_save_dir + 'gene_info_all.xlsx')
gene_info_df = NameRows_Gene(gene_info_df)
gene_info_df
# Out:
#                   gene_name    gene_chr  gene_start   gene_end gene_strand  \
# gene_id
# ENSG00000087086         FTL          19    48965301   48966878           +
# ENSG00000099194         SCD          10   100347124  100364834           +
# ENSG00000170323       FABP4           8    81478419   81483263           -
# ENSG00000211445        GPX3           5   151020438  151028993           +
# ENSG00000210082     MT-RNR2          MT        1671       3229           +
# ...                     ...         ...         ...        ...         ...
# ENSG00000276351     RF01973  KI270721.1       52666      52734           +
# ENSG00000275661     RF01974  KI270721.1       52895      53010           +
# ENSG00000277856  AC233755.2  KI270726.1       26241      26534           +
# ENSG00000275063  AC233755.1  KI270726.1       41444      41876           +
# ENSG00000268674  AC213203.1  KI270713.1       35407      35916           +
#
#                  gene_length    gene_biotype  \
# gene_id
# ENSG00000087086          878  protein_coding
# ENSG00000099194         5362  protein_coding
# ENSG00000170323         1396  protein_coding
# ENSG00000211445         3163  protein_coding
# ENSG00000210082         1559         Mt_rRNA
# ...                      ...             ...
# ENSG00000276351           69        misc_RNA
# ENSG00000275661          116        misc_RNA
# ENSG00000277856          294  protein_coding
# ENSG00000275063          351  protein_coding
# ENSG00000268674          510  protein_coding
#
#                                                   gene_description tf_family
# gene_id
# ENSG00000087086  ferritin light chain [Source:HGNC Symbol;Acc:H...         -
# ENSG00000099194  stearoyl-CoA desaturase [Source:HGNC Symbol;Ac...         -
# ENSG00000170323  fatty acid binding protein 4 [Source:HGNC Symb...         -
# ENSG00000211445  glutathione peroxidase 3 [Source:HGNC Symbol;A...         -
# ENSG00000210082  mitochondrially encoded 16S RNA [Source:HGNC S...         -
# ...                                                            ...       ...
# ENSG00000276351                                                NaN         -
# ENSG00000275661                                                NaN         -
# ENSG00000277856                                                NaN         -
# ENSG00000275063  immunoglobulin heavy variable 4-38-2-like [Sou...         -
# ENSG00000268674  Protein FAM231C  [Source:UniProtKB/Swiss-Prot;...         -
#
# [58735 rows x 9 columns]

# %%
# Only keep non-NaN genes for DESeq2 analysis

# Remove genes that have NaN counts in normalized counts df from gene_info_df
genes_to_keep = ~df.isna().any(axis=1)
gene_info_df = gene_info_df.loc[genes_to_keep]

# Remove genes that have NaN counts from normalized counts df
df = df.dropna()
df.to_excel(Normalized_counts_save_dir + '2_normalized_count_NaN_removed.xlsx')

df # Visualize
# Out:
#                         Ctrl1         Ctrl2         Ctrl3           YY1  \
# gene_id
# ENSG00000087086  1.220955e+06  1.141922e+06  1.031176e+06  1.403261e+06
# ENSG00000099194  9.544785e+05  7.815641e+05  5.275813e+05  1.004424e+06
# ENSG00000170323  5.002016e+05  4.500698e+05  3.202915e+05  5.480002e+05
# ENSG00000211445  3.232648e+05  2.100729e+05  2.740406e+05  2.414436e+05
# ENSG00000210082  1.583665e+05  1.341154e+05  8.039464e+04  2.713054e+05
# ...                       ...           ...           ...           ...
# ENSG00000276351  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ENSG00000
# OY1                  0.0              0.0              0.0              0.0
# OY2                  0.0              0.0              0.0              0.0
# OY3                  0.0              0.0              0.0              0.0
# OO1                  0.0              0.0              0.0              0.0
# OO2                  0.0              0.0              0.0              0.0
# OO3                  0.0              0.0              0.0              0.0
# OY3_1                0.0              0.0              0.0              0.0
#
# gene_id  ENSG00000276351  ENSG00000275661  ENSG00000277856  ENSG00000275063  \
# Ctrl1                0.0              0.0              0.0              0.0
# Ctrl2                0.0              0.0              0.0              0.0
# Ctrl3                0.0              0.0              0.0              0.0
# YY1                  0.0              0.0              0.0              0.0
# YY2                  0.0              0.0              0.0              0.0
# YY3                  0.0              0.0              0.0              0.0
# YO1                  0.0              0.0              0.0              0.0
# YO2                  0.0              0.0              0.0              0.0
# YO3                  0.0              0.0              0.0              0.0
# OY1                  0.0              0.0              0.0              0.0
# OY2                  0.0              0.0              0.0              0.0
# OY3                  0.0              0.0              0.0              0.0
# OO1                  0.0              0.0              0.0              0.0
# OO2                  0.0              0.0              0.0              0.0
# OO3                  0.0              0.0              0.0              0.0
# OY3_1                0.0              0.0              0.0              0.0
#
# gene_id  ENSG00000268674
# Ctrl1                0.0
# Ctrl2                0.0
# Ctrl3                0.0
# YY1                  0.0
# YY2                  0.0
# YY3                  0.0
# YO1                  0.0
# YO2                  0.0
# YO3                  0.0
# OY1                  0.0
# OY2                  0.0
# OY3                  0.0
# OO1                  0.0
# OO2                  0.0
# OO3                  0.0
# OY3_1                0.0
#
# [16 rows x 58735 columns]

# %%
# Data filtering for DESeq2
# We filter out genes that have less than 10 counts in total (of all samples)

genes_to_keep = df.columns[df.sum(axis=0) >= 10]
counts_df = df[genes_to_keep]
gene_info_df = gene_info_df.T[genes_to_keep].T

print(f"{len(counts_df.columns)} genes are kept after data filtering; gene info file is also reduced to {len(gene_info_df.index)}")
# Out:
# 28017 genes are kept after data filtering; gene info file is also reduced to 28017

# %%
gene_info_df.to_excel(Normalized_counts_save_dir + 'gene_info_filtered.xlsx')

# %%
counts_df.T.to_excel(Normalized_counts_save_dir + '3_counts_df_Transpose_filtered.xlsx')

# %%
# Perform paired DEA with pydeseq2(version-0.4.1) on pre-normalized data (skip MOR normalization of DESeq2, since we have previously done it)

def Prenormed_Paired_DESeq2_Analysis(counts_df, metadata, gene_info, size_factors, design_factor, exp_condition, ref_condition, savedir):
    """
    IMPORTANT: this function can only be used when counts are pre-normalized. In this current use case, input counts are pre-normalized with first median of ratios, and then scaled to reduce biological batch effects of the chips
    
    This function puts several steps of DESeq2 pipeline together so that analysis of DEG across different conditions within a large dataset and be performed easier.
    
    This function returns stat_res.results_df before lfc shrinkage for LFC shrinkage and volcano plot.
    
    This function will save stat_res.results_df merged with gene info and normalized counts of each sample in the given savedir
    
    This function contains these following steps:
    a) Retrieve count/metadata of samples in the indicated comparison pair: exp_condition vs ref_condition
    b) New dataframes (count and metadata) that only contains samples that we wish to make comparison with will be used to construct dds
    c) Before proceeding to DESeq2, exp_condition and ref_condition will be modified: replacing "_" with "-"
    d) Constructing dds and perform DEA in a step-by-step manner
    e) Perform Wald test with default setting: LFC is divided by its standard error, resulting in a z-statistic, which is compared to a standard normal distribution.
    f) After P value determination, results_df of stat_res without LFC shrinkage will returned for further analysis
    g) On the other hand, 
    
    :param counts_df: is a dataframe that contains counts info have have no NaN (zero in counts_df will be filtered out before analysis)
    :param metadata: is a dataframe that contains metadata
    :param gene_info: is a dataframe that contains ensembl ID as indexes, other gene info, including gene symbols, in columns.
    :param size_factors: is a np.array that contains the size factors that were used in the median of ratio normalization step
    :param design_factor: is the factor that you want to make comparison on
    :param ref_condition: is one of the conditions in the coresponding design_factor that you wish to use as reference in comparison
    :param exp_condition: experimental condition
    :param savedir: save directory
    
    :return: stat_res of DESeq2
    """
    from pydeseq2.dds import DeseqDataSet
    from pydeseq2.ds import DeseqStats
    
    # Find the samples that will not be used in this comparison
    drop_indexes = metadata.index[~metadata[design_factor].isin([exp_condition, ref_condition])].tolist()
    
    # Drop the not needed samples from counts_df and metadata
    counts_df_drop = counts_df.drop(drop_indexes, axis = 0)
    metadata_drop = metadata.drop(drop_indexes, axis=0)
    
    # Modify compared condition annotation to match with DESeq2 output
    exp_condition_modified = exp_condition.replace('_','-')
    ref_condition_modified = ref_condition.replace('_','-')
    
    # Make all datas are integers (round up to prevent making a non-zero count to zero)
    counts_df_drop_int = counts_df_drop.apply(np.ceil).astype(int)
    
    # Make sure that counts_df_drop and metadata_drop have the same group of indexes
    if counts_df_drop_int.index.equals(metadata_drop.index):
        # Proceed
        print('Proceeding to dds object construction')
    else: 
        print("Error: Indexes of compared counts_df_drop and metadata_drop are not identical.")
        return

    # Build DESeq2 object   
    dds = DeseqDataSet(
        counts=counts_df_drop_int,
        metadata=metadata_drop,
        design_factors=design_factor,
        ref_level=[design_factor, ref_condition_modified],
        refit_cooks=True,
        n_cpus=8,
    )
    
    # Select the size factors of the desired samples
    selected_size_factors_list = []
    for i in range(len(metadata.index)):
        if metadata.index[i] in drop_indexes:
            continue
        else:
            selected_size_factors_list.append(size_factors[i])
        
    selected_size_factors = np.array(selected_size_factors_list)
    
    # add previous normed_counts results to dds
    dds.layers['normed_counts'] = counts_df_drop
    dds.obsm['size_factors'] = selected_size_factors
    
    # Save normalized counts in dataframe for future use
    normalized_counts_df = pd.DataFrame(dds.layers['normed_counts'], columns=counts_df_drop.columns, index=counts_df_drop.index).T
    
    # Fit genewise dispersions
    dds.fit_genewise_dispersions()
    
    # Fit dispersion trend coefficients
    dds.fit_dispersion_trend()
    
    # Dispersion priors
    dds.fit_dispersion_prior()
    
    # MAP Dispersions
    dds.fit_MAP_dispersions()
    
    # Fit log fold changes (This lfc is stored in natural log scale, different from the output log2fc)
    dds.fit_LFC()
    
    # Calculate Cooks distances and refit
    dds.calculate_cooks()
    if dds.refit_cooks:
        # Replace outlier counts
        dds.refit()
        
    # Compute p-values and adjusted p-values with DeseqStats, which applies Wald tests to compute p-values
    stat_res = DeseqStats(dds, contrast=[design_factor, exp_condition_modified, ref_condition_modified], independent_filter=True)
    # Compute Wald test
    stat_res.summary()
    
    # Extract results_df from stat_res
    results_df = stat_res.results_df
    
    # Save a DESeq2 result file with gene_info, results_df, and normalized counts
    merged_df = pd.concat([gene_info, results_df, normalized_counts_df], axis=1)
    merged_df.to_excel(savedir + f'0_results_{exp_condition_modified}_vs_{ref_condition_modified}_before_LFC_shrinkage.xlsx')
    
    # Find significantly up/down/all regulated DEgenes
    up_DEG = merged_df[(merged_df['log2FoldChange']>=1)&(merged_df['padj']<=0.05)]
    down_DEG = merged_df[(merged_df['log2FoldChange']<=-1)&(merged_df['padj']<=0.05)]
    all_DEG = pd.concat([up_DEG, down_DEG], axis=0)
    
    up_DEG.to_excel(savedir + f'1_UP_DEGs_of_{exp_condition_modified}_vs_{ref_condition_modified}.xlsx')
    down_DEG.to_excel(savedir + f'2_DOWN_DEGs_of_{exp_condition_modified}_vs_{ref_condition_modified}.xlsx')
    all_DEG.to_excel(savedir + f'3_ALL_DEGs_of_{exp_condition_modified}_vs_{ref_condition_modified}.xlsx')
    
    return stat_res

# %%
# volcano plot plotting function for visualization of DEA results

def shrink_and_volcano(stat_res, gene_info, design_factor, exp_condition, ref_condition, savedir):
    """
    
    This function uses lfc_shrink() function of DESeq2 to perform LFC shrinkage and creates volcano plot out of it.
    Volcano plot will be plotted with the volcano_plot function right after this function, so always load the two volcano together
    
    :param res_df: results_df of stat_res before shrinkage
    :param gene_info: the gene_info dataframe for gene symbol annotation on volcano plot
    :param design_factor: is the factor that you want to make comparison on
    :param exp_condition: the experimental condtiion
    :param ref_condition: is one of the conditions in the coresponding design_factor that you wish to use as reference in comparison
    :param savedir: save directory
    
    :return: none
    
    """
    
    from pydeseq2.dds import DeseqDataSet
    from pydeseq2.ds import DeseqStats
    
    # Modify compared condition annotation to match with DESeq2 output
    exp_condition_modified = exp_condition.replace('_','-')
    ref_condition_modified = ref_condition.replace('_','-')
    
    # LFC shrinkage
    stat_res.lfc_shrink(coeff = f'{design_factor}_{exp_condition_modified}_vs_{ref_condition_modified}')
    shrunk_results_df = stat_res.results_df
    
    # Find significantly up/down/all regulated DEgenes in shrunk_results_df for volcano plot
    up_shrunk = shrunk_results_df[(shrunk_results_df['log2FoldChange']>=1)&(shrunk_results_df['padj']<=0.05)]
    down_shrunk = shrunk_results_df[(shrunk_results_df['log2FoldChange']<=-1)&(shrunk_results_df['padj']<=0.05)]
    
    # Draw volcano plot
    volcano_plot(shrunk_results_df, gene_info=gene_info,
                 save_dir = (savedir + f'volcano_plot_{exp_condition}_vs_{ref_condition}.pdf'))
    
    return

# volcano plot plotting function for visualization of DEA results

def volcano_plot(df, gene_info, save_dir):
    """
    Volcano plot for DESeq2 pipeline
    significance: log2FoldChange <= -1 / >= 1, padj <= 0.01
    Top 10 DE genes of each end are annotated
    """
    
    import matplotlib.pylab as plt
    import seaborn as sns
    from adjustText import adjust_text
    
    plt.figure(figsize=(8, 6))

    plt.scatter(x=df['log2FoldChange'],y=df['padj'].apply(lambda x:-np.log10(x)),s=3)

    # highlight down- or up- regulated genes
    down = df[(df['log2FoldChange']<=-1)&(df['padj']<=0.05)]
    up = df[(df['log2FoldChange']>=1)&(df['padj']<=0.05)]

    plt.scatter(x=down['log2FoldChange'],y=down['padj'].apply(lambda x:-np.log10(x)),s=5,color="blue")
    plt.scatter(x=up['log2FoldChange'],y=up['padj'].apply(lambda x:-np.log10(x)),s=5,color="red")
    
    # Select top 10 genes of each end for gene name annotation
    if len(down.index) >= 10:
        down_sorted = down.sort_values(by='padj', ascending=True)
        down_top_10 = down_sorted.head(10)
    else:
        down_top_10 = down
    
    if len(up.index) >= 10:
        up_sorted = up.sort_values(by='padj', ascending=True)
        up_top_10 = up_sorted.head(10)
    else:
        up_top_10 = up
    
    texts=[]
    for i,r in down_top_10.iterrows():
        texts.append(plt.text(x=r['log2FoldChange'],y=-np.log10(r['padj']),s=gene_info.loc[i,'gene_name']))
    for i,r in up_top_10.iterrows():
        texts.append(plt.text(x=r['log2FoldChange'],y=-np.log10(r['padj']),s=gene_info.loc[i,'gene_name']))
        
    if len(texts) > 0:
        adjust_text(texts,arrowprops=dict(arrowstyle="-", color='black', lw=0.5))
    else:
        print('No significant DEG')
        
    plt.xlabel("log2FC")
    plt.ylabel("-logFDR")
    plt.axvline(-1,color="grey",linestyle="--")
    plt.axvline(1,color="grey",linestyle="--")
    plt.axhline(-np.log10(0.05),color="grey",linestyle="--")
    plt.savefig(save_dir)
    return

# %%
# deglist savedir of current analysis
deglist_savedir = '/Volumes/Elements/20240213_Serum_Change_RNAseq_novogene/Results_Yuchen/2_DESeq2/1_deglist/'

# %%
# Read in size factors from MOR normalization step
size_factors = np.loadtxt(Normalized_counts_save_dir + 'SizeFactor.csv', delimiter=',')

# %%
# build savedir for Het_OY vs Iso_Old DEA results
Het_OY_vs_Iso_Old_savedir = deglist_savedir + '1.Het_OY_vs_Iso_Old/'

# Run DESeqAnalysis_Pipeline to compare Het_OY_vs_Iso_Old
Het_OY_vs_Iso_Old_stat_res = Prenormed_Paired_DESeq2_Analysis(counts_df=counts_df, 
                                                     metadata=metadata, 
                                                     gene_info=gene_info_df,
                                                     size_factors=size_factors,
                                                     design_factor='condition', 
                                                     exp_condition='Het_OY', 
                                                     ref_condition='Iso_Old', 
                                                     savedir = Het_OY_vs_Iso_Old_savedir)
Het_OY_vs_Iso_Old_stat_res
# Out:
# Proceeding to dds object construction
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(
# Fitting dispersions...
# ... done in 8.75 seconds.
#
# Fitting dispersion trend curve...
# ... done in 6.28 seconds.
#
# Fitting MAP dispersions...
# ... done in 8.73 seconds.
#
# Fitting LFCs...
# ... done in 5.52 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition Het-OY vs Iso-Old
# ... done in 2.21 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  666777.236243       -0.135062  0.286223 -0.471878  0.637014
# ENSG00000099194  195347.443214        0.162934  0.743999  0.218998  0.826652
# ENSG00000170323  329880.712378        0.199548  0.418387  0.476947  0.633400
# ENSG00000211445  153586.829930       -0.133400  0.336446 -0.396499  0.691737
# ENSG00000210082  118779.031074        0.163651  0.398370  0.410801  0.681219
# ...                        ...             ...       ...       ...       ...
# ENSG00000225624       0.268462       -0.261796  3.733990 -0.070112  0.944105
# ENSG00000231392       0.000000             NaN       NaN       NaN       NaN
# ENSG00000284070       0.238159       -1.840834  3.921207 -0.469456  0.638744
# ENSG00000237015       0.134257        0.699990  4.202332  0.166572  0.867707
# ENSG00000235701       0.000000             NaN       NaN       NaN       NaN
#
#                      padj
# gene_id
# ENSG00000087086  0.999902
# ENSG00000099194  0.999902
# ENSG00000170323  0.999902
# ENSG00000211445  0.999902
# ENSG00000210082  0.999902
# ...                   ...
# ENSG00000225624  0.999902
# ENSG00000231392       NaN
# ENSG00000284070  0.999902
# ENSG00000237015  0.999902
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]

# %%
# Het_OY_vs_Iso_Old shrink and volcano
shrink_and_volcano(Het_OY_vs_Iso_Old_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='Het_OY', 
                   ref_condition='Iso_Old', 
                   savedir = Het_OY_vs_Iso_Old_savedir)
# Out:
# Fitting MAP LFCs...
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/utils.py:1220: RuntimeWarning: overflow encountered in exp
#   counts - (counts + size) / (1 + size * np.exp(-xbeta - offset))
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/utils.py:1220: RuntimeWarning: overflow encountered in exp
#   counts - (counts + size) / (1 + size * np.exp(-xbeta - offset))
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/utils.py:1220: RuntimeWarning: overflow encountered in exp
#   counts - (counts + size) / (1 + size * np.exp(-xbeta - offset))
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/utils.py:1220: RuntimeWarning: overflow encountered in exp
#   counts - (counts + size) / (1 + size * np.exp(-xbeta - offset))
# Shrunk log2 fold change & Wald test p-value: condition Het-OY vs Iso-Old
# ... done in 27.19 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  666777.236243    3.358709e+00  0.337182 -0.471878  0.637014
# ENSG00000099194  195347.443214    1.624762e+00  0.759040  0.218998  0.826652
# ENSG00000170323  329880.712378    2.435331e+00  0.383943  0.476947  0.633400
# ENSG00000211445  153586.829930    2.417247e+00  0.385461 -0.396499  0.691737
# ENSG00000210082  118779.031074    2.261767e+00  0.411907  0.410801  0.681219
# ...                        ...             ...       ...       ...       ...
# ENSG00000225624       0.268462   -3.335029e-08  0.001478 -0.070112  0.944105
# ENSG00000231392       0.000000             NaN       NaN       NaN       NaN
# ENSG00000284070       0.238159   -2.225633e-07  0.001115 -0.469456  0.638744
# ENSG00000237015       0.134257    1.245087e-07  0.002458  0.166572  0.867707
# ENSG00000235701       0.000000             NaN       NaN       NaN       NaN
#
#                      padj
# gene_id
# ENSG00000087086  0.999902
# ENSG00000099194  0.999902
# ENSG00000170323  0.999902
# ENSG00000211445  0.999902
# ENSG00000210082  0.999902
# ...                   ...
# ENSG00000225624  0.999902
# ENSG00000231392       NaN
# ENSG00000284070  0.999902
# ENSG00000237015  0.999902
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]
# No significant DEG

# %%
# build savedir for Het_YO vs Iso_Young DEA results
Het_YO_vs_Iso_Young_savedir = deglist_savedir + '2.Het_YO_vs_Iso_Young/'

# Run DESeqAnalysis_Pipeline to compare Het_YO_vs_Iso_Young
Het_YO_vs_Iso_Young_stat_res = Prenormed_Paired_DESeq2_Analysis(counts_df=counts_df, 
                                                     metadata=metadata, 
                                                     gene_info=gene_info_df,
                                                     size_factors=size_factors,
                                                     design_factor='condition', 
                                                     exp_condition='Het_YO', 
                                                     ref_condition='Iso_Young', 
                                                     savedir = Het_YO_vs_Iso_Young_savedir)
Het_YO_vs_Iso_Young_stat_res
# Out:
# Proceeding to dds object construction
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(
# Fitting dispersions...
# ... done in 8.63 seconds.
#
# Fitting dispersion trend curve...
# ... done in 6.17 seconds.
#
# Fitting MAP dispersions...
# ... done in 8.49 seconds.
#
# Fitting LFCs...
# ... done in 4.97 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition Het-YO vs Iso-Young
# ... done in 1.84 seconds.
#                      baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  1.193492e+06        0.250979  0.285139  0.880197  0.378752
# ENSG00000099194  9.097974e+05        0.667713  0.393767  1.695705  0.089942
# ENSG00000170323  4.894909e+05        0.081130  0.200921  0.403789  0.686368
# ENSG00000211445  2.371398e+05        0.180660  0.226936  0.796084  0.425983
# ENSG00000210082  2.156495e+05        0.324943  0.314406  1.033515  0.301363
# ...                       ...             ...       ...       ...       ...
# ENSG00000225624  3.904413e-01        3.077213  4.027375  0.764074  0.444823
# ENSG00000231392  1.071969e+00        4.010988  3.351228  1.196871  0.231357
# ENSG00000284070  6.431812e-01        3.201667  3.852115  0.831145  0.405892
# ENSG00000237015  1.103344e+00        2.903503  2.499141  1.161801  0.245316
# ENSG00000235701  1.194049e+00        1.287501  2.362077  0.545072  0.585704
#
#                      padj
# gene_id
# ENSG00000087086  0.934502
# ENSG00000099194  0.907829
# ENSG00000170323  0.964109
# ENSG00000211445  0.945348
# ENSG00000210082  0.921448
# ...                   ...
# ENSG00000225624  0.946207
# ENSG00000231392  0.913184
# ENSG00000284070  0.938569
# ENSG00000237015  0.913782
# ENSG00000235701  0.958785
#
# [28017 rows x 6 columns]

# %%
# Het_YO_vs_Iso_Young shrink and volcano
shrink_and_volcano(Het_YO_vs_Iso_Young_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]

# %%
# Iso_Young_vs_Iso_Old shrink and volcano
shrink_and_volcano(Iso_Young_vs_Iso_Old_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='Iso_Young', 
                   ref_condition='Iso_Old', 
                   savedir = Iso_Young_vs_Iso_Old_savedir)
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition Iso-Young vs Iso-Old
# ... done in 9.05 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  936805.272666        3.705117  0.284361  3.922877  0.000087
# ENSG00000099194  462529.560866        3.609337  0.422307  4.439174  0.000009
# ENSG00000170323  403183.355608        3.729774  0.401705  2.648726  0.008080
# ENSG00000211445  201513.436910        0.728878  0.242274  3.411252  0.000647
# ENSG00000210082  155687.858793        3.005248  0.457860  2.902548  0.003701
# ...                        ...             ...       ...       ...       ...
# ENSG00000225624       0.156573       -0.021393  0.458488 -0.165450  0.868590
# ENSG00000231392       0.000000             NaN       NaN       NaN       NaN
# ENSG00000284070       0.277852       -0.025854  0.441541 -0.367405  0.713317
# ENSG00000237015       0.146414        0.021353  0.949256  0.268969  0.787954
# ENSG00000235701       0.336474        0.032790  1.407642  0.666996  0.504775
#
#                      padj
# gene_id
# ENSG00000087086  0.001870
# ENSG00000099194  0.000295
# ENSG00000170323  0.058061
# ENSG00000211445  0.008987
# ENSG00000210082  0.033515
# ...                   ...
# ENSG00000225624       NaN
# ENSG00000231392       NaN
# ENSG00000284070       NaN
# ENSG00000237015       NaN
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]

# %%
# build savedir for Het_YO vs Het_OY DE results
Het_YO_vs_Het_OY_savedir = deglist_savedir + '4.Het_YO_vs_Het_OY/use_padj/'

# Run DESeqAnalysis_Pipeline to compare Het_YO_vs_Het_OY
Het_YO_vs_Het_OY_stat_res = Prenormed_Paired_DESeq2_Analysis(counts_df=counts_df, 
                                                     metadata=metadata, 
                                                     gene_info=gene_info_df,
                                                     size_factors=size_factors,
                                                     design_factor='condition', 
                                                     exp_condition='Het_YO', 
                                                     ref_condition='Het_OY', 
                                                     savedir = Het_YO_vs_Het_OY_savedir)
Het_YO_vs_Het_OY_stat_res
# Out:
# Proceeding to dds object construction
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(
# Fitting dispersions...
# ... done in 9.06 seconds.
#
# Fitting dispersion trend curve...
# ... done in 6.33 seconds.
#
# Fitting MAP dispersions...
# ... done in 9.74 seconds.
#
# Fitting LFCs...
# ... done in 5.73 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition Het-YO vs Het-OY
# ... done in 1.83 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat  \
# gene_id
# ENSG00000087086  886794.660510        1.345529  0.314054  4.284394
# ENSG00000099194  578719.887208        2.763049  0.435922  6.338403
# ENSG00000170323  403858.601491        0.807065  0.355029  2.273236
# ENSG00000211445  184123.720496        1.125968  0.328117  3.431609
# ENSG00000210082  170174.722107        1.275728  0.353134  3.612587
# ...                        ...             ...       ...       ...
# ENSG00000225624       0.468921        2.604939  2.902760  0.897401
# ENSG00000231392       0.918830        4.259728  2.907756  1.464954
# ENSG00000284070       0.551298        3.450384  3.369514  1.024000
# ENSG00000237015       0.954483        3.394465  2.327048  1.458700
# ENSG00000235701       0.735064        4.037655  3.092645  1.305567
#
#                        pvalue          padj
# gene_id
# ENSG00000087086  1.832378e-05  2.987727e-04
# ENSG00000099194  2.321582e-10  1.529856e-08
# ENSG00000170323  2.301194e-02  7.835215e-02
# ENSG00000211445  6.000119e-04  4.927174e-03
# ENSG00000210082  3.031575e-04  2.866254e-03
# ...                       ...           ...
# ENSG00000225624  3.695051e-01           NaN
# ENSG00000231392  1.429335e-01           NaN
# ENSG00000284070  3.058351e-01           NaN
# ENSG00000237015  1.446477e-01           NaN
# ENSG00000235701  1.916999e-01           NaN
#
# [28017 rows x 6 columns]

# %%
# Het_YO_vs_Het_OY shrink and volcano
shrink_and_volcano(Het_YO_vs_Het_OY_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='Het_YO', 
                   ref_condition='Het_OY', 
                   savedir = Het_YO_vs_Het_OY_savedir)
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition Het-YO vs Het-OY
# ... done in 10.24 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat  \
# gene_id
# ENSG00000087086  886794.660510        4.382488  0.350653  4.284394
# ENSG00000099194  578719.887208        4.077550  0.328815  6.338403
# ENSG00000170323  403858.601491        3.290696  0.400116  2.273236
# ENSG00000211445  184123.720496        3.495360  0.454481  3.431609
# ENSG00000210082  170174.722107        3.383577  0.446894  3.612587
# ...                        ...             ...       ...       ...
# ENSG00000225624       0.468921        0.102034  1.089971  0.897401
# ENSG00000231392       0.918830        0.185376  1.885202  1.464954
# ENSG00000284070       0.551298        0.117196  1.773394  1.024000
# ENSG00000237015       0.954483        0.217447  1.199224  1.458700
# ENSG00000235701       0.735064        0.153293  1.909892  1.305567
#
#                        pvalue          padj
# gene_id
# ENSG00000087086  1.832378e-05  2.987727e-04
# ENSG00000099194  2.321582e-10  1.529856e-08
# ENSG00000170323  2.301194e-02  7.835215e-02
# ENSG00000211445  6.000119e-04  4.927174e-03
# ENSG00000210082  3.031575e-04  2.866254e-03
# ...                       ...           ...
# ENSG00000225624  3.695051e-01           NaN
# ENSG00000231392  1.429335e-01           NaN
# ENSG00000284070  3.058351e-01           NaN
# ENSG00000237015  1.446477e-01           NaN
# ENSG00000235701  1.916999e-01           NaN
#
# [28017 rows x 6 columns]

# %%
# Perform paired DEA with pydeseq2(version-0.4.1) on pre-normalized data (skip MOR normalization of DESeq2, since we have previously done it)
# Use pvalue as DEG threshold

def Prenormed_Paired_DESeq2_Analysis_pvalue(counts_df, metadata, gene_info, size_factors, design_factor, exp_condition, ref_condition, savedir):
    """
    IMPORTANT: this function can only be used when counts are pre-normalized. In this current use case, input counts are pre-normalized with first median of ratios, and then scaled to reduce biological batch effects of the chips
    
    This function puts several steps of DESeq2 pipeline together so that analysis of DEG across different conditions within a large dataset and be performed easier.
    
    This function returns stat_res.results_df before lfc shrinkage for LFC shrinkage and volcano plot.
    
    This function will save stat_res.results_df merged with gene info and normalized counts of each sample in the given savedir
    
    This function contains these following steps:
    a) Retrieve count/metadata of samples in the indicated comparison pair: exp_condition vs ref_condition
    b) New dataframes (count and metadata) that only contains samples that we wish to make comparison with will be used to construct dds
    c) Before proceeding to DESeq2, exp_condition and ref_condition will be modified: replacing "_" with "-"
    d) Constructing dds and perform DEA in a step-by-step manner
    e) Perform Wald test with default setting: LFC is divided by its standard error, resulting in a z-statistic, which is compared to a standard normal distribution.
    f) After P value determination, results_df of stat_res without LFC shrinkage will returned for further analysis
    g) On the other hand, 
    
    :param counts_df: is a dataframe that contains counts info have have no NaN (zero in counts_df will be filtered out before analysis)
    :param metadata: is a dataframe that contains metadata
    :param gene_info: is a dataframe that contains ensembl ID as indexes, other gene info, including gene symbols, in columns.
    :param size_factors: is a np.array that contains the size factors that were used in the median of ratio normalization step
    :param design_factor: is the factor that you want to make comparison on
    :param ref_condition: is one of the conditions in the coresponding design_factor that you wish to use as reference in comparison
    :param savedir: save directory
    
    """
    from pydeseq2.dds import DeseqDataSet
    from pydeseq2.ds import DeseqStats
    
    # Find the samples that will not be used in this comparison
    drop_indexes = metadata.index[~metadata[design_factor].isin([exp_condition, ref_condition])].tolist()
    
    # Drop the not needed samples from counts_df and metadata
    counts_df_drop = counts_df.drop(drop_indexes, axis = 0)
    metadata_drop = metadata.drop(drop_indexes, axis=0)
    
    # Modify compared condition annotation to match with DESeq2 output
    exp_condition_modified = exp_condition.replace('_','-')
    ref_condition_modified = ref_condition.replace('_','-')
    
    # Make all datas are integers (round up to prevent making a non-zero count to zero)
    counts_df_drop_int = counts_df_drop.apply(np.ceil).astype(int)
    
    # Make sure that counts_df_drop and metadata_drop have the same group of indexes
    if counts_df_drop_int.index.equals(metadata_drop.index):
        # Proceed
        print('Proceeding to dds object construction')
    else: 
        print("Error: Indexes of compared counts_df_drop and metadata_drop are not identical.")
        return

    # Build DESeq2 object   
    dds = DeseqDataSet(
        counts=counts_df_drop_int,
        metadata=metadata_drop,
        design_factors=design_factor,
        ref_level=[design_factor, ref_condition_modified],
        refit_cooks=True,
        n_cpus=8,
    )
    
    # Select the size factors of the desired samples
    selected_size_factors_list = []
    for i in range(len(metadata.index)):
        if metadata.index[i] in drop_indexes:
            continue
        else:
            selected_size_factors_list.append(size_factors[i])
        
    selected_size_factors = np.array(selected_size_factors_list)
    
    # add previous normed_counts results to dds
    dds.layers['normed_counts'] = counts_df_drop
    dds.obsm['size_factors'] = selected_size_factors
    
    # Save normalized counts in dataframe for future use
    normalized_counts_df = pd.DataFrame(dds.layers['normed_counts'], columns=counts_df_drop.columns, index=counts_df_drop.index).T
    
    # Fit genewise dispersions
    dds.fit_genewise_dispersions()
    
    # Fit dispersion trend coefficients
    dds.fit_dispersion_trend()
    
    # Dispersion priors
    dds.fit_dispersion_prior()
    
    # MAP Dispersions
    dds.fit_MAP_dispersions()
    
    # Fit log fold changes (This lfc is stored in natural log scale, different from the output log2fc)
    dds.fit_LFC()
    
    # Calculate Cooks distances and refit
    dds.calculate_cooks()
    if dds.refit_cooks:
        # Replace outlier counts
        dds.refit()
        
    # Compute p-values and adjusted p-values with DeseqStats, which applies Wald tests to compute p-values
    stat_res = DeseqStats(dds, contrast=[design_factor, exp_condition_modified, ref_condition_modified], independent_filter=True)
    # Compute Wald test
    stat_res.summary()
    
    # Extract results_df from stat_res
    results_df = stat_res.results_df
    
    # Save a DESeq2 result file with gene_info, results_df, and normalized counts
    merged_df = pd.concat([gene_info, results_df, normalized_counts_df], axis=1)
    merged_df.to_excel(savedir + f'0_results_{exp_condition_modified}_vs_{ref_condition_modified}_before_LFC_shrinkage.xlsx')
    
    # Find significantly up/down/all regulated DEgenes
    up_DEG = merged_df[(merged_df['log2FoldChange']>=1)&(merged_df['pvalue']<=0.05)]
    down_DEG = merged_df[(merged_df['log2FoldChange']<=-1)&(merged_df['pvalue']<=0.05)]
    all_DEG = pd.concat([up_DEG, down_DEG], axis=0)
    
    up_DEG.to_excel(savedir + f'1_UP_DEGs_of_{exp_condition_modified}_vs_{ref_condition_modified}.xlsx')
    down_DEG.to_excel(savedir + f'2_DOWN_DEGs_of_{exp_condition_modified}_vs_{ref_condition_modified}.xlsx')
    all_DEG.to_excel(savedir + f'3_ALL_DEGs_of_{exp_condition_modified}_vs_{ref_condition_modified}.xlsx')
    
    return stat_res

# %%
# volcano plot plotting function for visualization of DEA results
# Use pvalue threshold

def shrink_and_volcano_pvalue(stat_res, gene_info, design_factor, exp_condition, ref_condition, savedir):
    """
    
    This function uses lfc_shrink() function of DESeq2 to perform LFC shrinkage and creates volcano plot out of it.
    Volcano plot will be plotted with the volcano_plot function right after this function, so always load the two volcano together
    
    :param res_df: results_df of stat_res before shrinkage
    :param gene_info: the gene_info dataframe for gene symbol annotation on volcano plot
    :param design_factor: is the factor that you want to make comparison on
    :param exp_condition: the experimental condtiion
    :param ref_condition: is one of the conditions in the coresponding design_factor that you wish to use as reference in comparison
    :param savedir: save directory
    
    :return: none
    
    """
    
    from pydeseq2.dds import DeseqDataSet
    from pydeseq2.ds import DeseqStats
    
    # Modify compared condition annotation to match with DESeq2 output
    exp_condition_modified = exp_condition.replace('_','-')
    ref_condition_modified = ref_condition.replace('_','-')
    
    # LFC shrinkage
    stat_res.lfc_shrink(coeff = f'{design_factor}_{exp_condition_modified}_vs_{ref_condition_modified}')
    shrunk_results_df = stat_res.results_df
    
    # Find significantly up/down/all regulated DEgenes in shrunk_results_df for volcano plot
    up_shrunk = shrunk_results_df[(shrunk_results_df['log2FoldChange']>=1)&(shrunk_results_df['pvalue']<=0.05)]
    down_shrunk = shrunk_results_df[(shrunk_results_df['log2FoldChange']<=-1)&(shrunk_results_df['pvalue']<=0.05)]
    
    # Draw volcano plot
    volcano_plot_pvalue(shrunk_results_df, gene_info=gene_info,
                 save_dir = (savedir + f'volcano_plot_{exp_condition}_vs_{ref_condition}.pdf'))
    
    return

# volcano plot plotting function for visualization of DEA results

def volcano_plot_pvalue(df, gene_info, save_dir):
    """
    Volcano plot for DESeq2 pipeline
    significance: log2FoldChange <= -1 / >= 1, pval <= 0.05
    Top 10 DE genes of each end are annotated
    """
    
    import matplotlib.pylab as plt
    import seaborn as sns
    from adjustText import adjust_text
    
    plt.figure(figsize=(8, 6))

    plt.scatter(x=df['log2FoldChange'], y=df['pvalue'].apply(lambda x:-np.log10(x)),s=3)

    # highlight down- or up- regulated genes
    down = df[(df['log2FoldChange']<=-1)&(df['pvalue']<=0.05)]
    up = df[(df['log2FoldChange']>=1)&(df['pvalue']<=0.05)]

    plt.scatter(x=down['log2FoldChange'], y=down['pvalue'].apply(lambda x:-np.log10(x)),s=5,color="blue")
    plt.scatter(x=up['log2FoldChange'], y=up['pvalue'].apply(lambda x:-np.log10(x)),s=5,color="red")
    
    # Select top 10 genes of each end for gene name annotation
    if len(down.index) >= 10:
        down_sorted = down.sort_values(by='pvalue', ascending=True)
        down_top_10 = down_sorted.head(10)
    else:
        down_top_10 = down
    
    if len(up.index) >= 10:
        up_sorted = up.sort_values(by='pvalue', ascending=True)
        up_top_10 = up_sorted.head(10)
    else:
        up_top_10 = up
    
    texts=[]
    for i,r in down_top_10.iterrows():
        texts.append(plt.text(x=r['log2FoldChange'],y=-np.log10(r['pvalue']),s=gene_info.loc[i,'gene_name']))
    for i,r in up_top_10.iterrows():
        texts.append(plt.text(x=r['log2FoldChange'],y=-np.log10(r['pvalue']),s=gene_info.loc[i,'gene_name']))
        
    if len(texts) > 0:
        adjust_text(texts,arrowprops=dict(arrowstyle="-", color='black', lw=0.5))
    else:
        print('No significant DEG')
        
    plt.xlabel("log2FC")
    plt.ylabel("-log(p-value)")
    plt.axvline(-1,color="grey",linestyle="--")
    plt.axvline(1,color="grey",linestyle="--")
    plt.axhline(-np.log10(0.05),color="grey",linestyle="--")
    plt.savefig(save_dir)
    return

# %%
# build savedir for Het_OY vs Iso_Old DEA results
Het_OY_vs_Iso_Old_savedir = deglist_savedir + '1.Het_OY_vs_Iso_Old/use_pval/'

# Run DESeqAnalysis_Pipeline to compare Het_OY_vs_Iso_Old
Het_OY_vs_Iso_Old_stat_res = Prenormed_Paired_DESeq2_Analysis_pvalue(counts_df=counts_df, 
                                                     metadata=metadata, 
                                                     gene_info=gene_info_df,
                                                     size_factors=size_factors,
                                                     design_factor='condition', 
                                                     exp_condition='Het_OY', 
                                                     ref_condition='Iso_Old', 
                                                     savedir = Het_OY_vs_Iso_Old_savedir)
Het_OY_vs_Iso_Old_stat_res
# Out:
# Proceeding to dds object construction
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(
# Fitting dispersions...
# ... done in 8.40 seconds.
#
# Fitting dispersion trend curve...
# ... done in 6.21 seconds.
#
# Fitting MAP dispersions...
# ... done in 8.78 seconds.
#
# Fitting LFCs...
# ... done in 5.91 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition Het-OY vs Iso-Old
# ... done in 1.90 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  666777.236243       -0.135062  0.286223 -0.471878  0.637014
# ENSG00000099194  195347.443214        0.162934  0.743999  0.218998  0.826652
# ENSG00000170323  329880.712378        0.199548  0.418387  0.476947  0.633400
# ENSG00000211445  153586.829930       -0.133400  0.336446 -0.396499  0.691737
# ENSG00000210082  118779.031074        0.163651  0.398370  0.410801  0.681219
# ...                        ...             ...       ...       ...       ...
# ENSG00000225624       0.268462       -0.261796  3.733990 -0.070112  0.944105
# ENSG00000231392       0.000000             NaN       NaN       NaN       NaN
# ENSG00000284070       0.238159       -1.840834  3.921207 -0.469456  0.638744
# ENSG00000237015       0.134257        0.699990  4.202332  0.166572  0.867707
# ENSG00000235701       0.000000             NaN       NaN       NaN       NaN
#
#                      padj
# gene_id
# ENSG00000087086  0.999902
# ENSG00000099194  0.999902
# ENSG00000170323  0.999902
# ENSG00000211445  0.999902
# ENSG00000210082  0.999902
# ...                   ...
# ENSG00000225624  0.999902
# ENSG00000231392       NaN
# ENSG00000284070  0.999902
# ENSG00000237015  0.999902
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]

# %%
# Het_OY_vs_Iso_Old shrink and volcano
shrink_and_volcano_pvalue(Het_OY_vs_Iso_Old_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='Het_OY', 
                   ref_condition='Iso_Old', 
                   savedir = Het_OY_vs_Iso_Old_savedir)
# Out:
# Fitting MAP LFCs...
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/utils.py:1220: RuntimeWarning: overflow encountered in exp
#   counts - (counts + size) / (1 + size * np.exp(-xbeta - offset))
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/utils.py:1220: RuntimeWarning: overflow encountered in exp
#   counts - (counts + size) / (1 + size * np.exp(-xbeta - offset))
# Shrunk log2 fold change & Wald test p-value: condition Het-OY vs Iso-Old
# ... done in 22.98 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  666777.236243    3.358709e+00  0.337182 -0.471878  0.637014
# ENSG00000099194  195347.443214    1.624762e+00  0.759040  0.218998  0.826652
# ENSG00000170323  329880.712378    2.435331e+00  0.383943  0.476947  0.633400
# ENSG00000211445  153586.829930    2.417247e+00  0.385461 -0.396499  0.691737
# ENSG00000210082  118779.031074    2.261767e+00  0.411907  0.410801  0.681219
# ...                        ...             ...       ...       ...       ...
# ENSG00000225624       0.268462   -3.335029e-08  0.001478 -0.070112  0.944105
# ENSG00000231392       0.000000             NaN       NaN       NaN       NaN
# ENSG00000284070       0.238159   -2.225633e-07  0.001115 -0.469456  0.638744
# ENSG00000237015       0.134257    1.245087e-07  0.002458  0.166572  0.867707
# ENSG00000235701       0.000000             NaN       NaN       NaN       NaN
#
#                      padj
# gene_id
# ENSG00000087086  0.999902
# ENSG00000099194  0.999902
# ENSG00000170323  0.999902
# ENSG00000211445  0.999902
# ENSG00000210082  0.999902
# ...                   ...
# ENSG00000225624  0.999902
# ENSG00000231392       NaN
# ENSG00000284070  0.999902
# ENSG00000237015  0.999902
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]

# %%
# build savedir for Het_YO vs Iso_Young DEA results
Het_YO_vs_Iso_Young_savedir = deglist_savedir + '2.Het_YO_vs_Iso_Young/use_pval/'

# Run DESeqAnalysis_Pipeline to compare Het_YO_vs_Iso_Young
Het_YO_vs_Iso_Young_stat_res = Prenormed_Paired_DESeq2_Analysis_pvalue(counts_df=counts_df, 
                                                     metadata=metadata, 
                                                     gene_info=gene_info_df,
                                                     size_factors=size_factors,
                                                     design_factor='condition', 
                                                     exp_condition='Het_YO', 
                                                     ref_condition='Iso_Young', 
                                                     savedir = Het_YO_vs_Iso_Young_savedir)
Het_YO_vs_Iso_Young_stat_res
# Out:
# Proceeding to dds object construction
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(
# Fitting dispersions...
# ... done in 8.94 seconds.
#
# Fitting dispersion trend curve...
# ... done in 6.10 seconds.
#
# Fitting MAP dispersions...
# ... done in 7.86 seconds.
#
# Fitting LFCs...
# ... done in 5.25 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: condition Het-YO vs Iso-Young
# ... done in 2.07 seconds.
#                      baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  1.193492e+06        0.250979  0.285139  0.880197  0.378752
# ENSG00000099194  9.097974e+05        0.667713  0.393767  1.695705  0.089942
# ENSG00000170323  4.894909e+05        0.081130  0.200921  0.403789  0.686368
# ENSG00000211445  2.371398e+05        0.180660  0.226936  0.796084  0.425983
# ENSG00000210082  2.156495e+05        0.324943  0.314406  1.033515  0.301363
# ...                       ...             ...       ...       ...       ...
# ENSG00000225624  3.904413e-01        3.077213  4.027375  0.764074  0.444823
# ENSG00000231392  1.071969e+00        4.010988  3.351228  1.196871  0.231357
# ENSG00000284070  6.431812e-01        3.201667  3.852115  0.831145  0.405892
# ENSG00000237015  1.103344e+00        2.903503  2.499141  1.161801  0.245316
# ENSG00000235701  1.194049e+00        1.287501  2.362077  0.545072  0.585704
#
#                      padj
# gene_id
# ENSG00000087086  0.934502
# ENSG00000099194  0.907829
# ENSG00000170323  0.964109
# ENSG00000211445  0.945348
# ENSG00000210082  0.921448
# ...                   ...
# ENSG00000225624  0.946207
# ENSG00000231392  0.913184
# ENSG00000284070  0.938569
# ENSG00000237015  0.913782
# ENSG00000235701  0.958785
#
# [28017 rows x 6 columns]

# %%
# Het_YO_vs_Iso_Young shrink and volcano
shrink_and_volcano_pvalue(Het_YO_vs_Iso_Young_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='Het_YO', 
                   ref_condition='Iso_Young', 
                   savedir = Het_YO_vs_Iso_Young_savedir)
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition Het-YO vs Iso-Young
# ... done in 11.82 seconds.
#                      baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  1.193492e+06        4.746924  0.451413  0.880197  0.378752
# ENSG00000099194  9.097974e+05        3.477263  0.381314  1.695705  0.089942
# ENSG00000170323  4.894909e+05        2.389998  0.254904  0.403789  0.686368
# ENSG00000211445  2.371398e+05        0.554433  0.265712  0.796084  0.425983
# ENSG00000210082  2.156495e+05        3.738877  0.500824  1.033515  0.301363
# ...                       ...             ...       ...       ...       ...
# ENSG00000225624  3.904413e-01        0.002940  0.457635  0.764074  0.444823
# ENSG00000231392  1.071969e+00        0.004996  0.482490  1.196871  0.231357
# ENSG00000284070  6.431812e-01        0.003298  0.446826  0.831145  0.405892
# ENSG00000237015  1.103344e+00        0.006532  0.276285  1.161801  0.245316
# ENSG00000235701  1.194049e+00        0.003119  0.205698  0.545072  0.585704
#
#                      padj
# gene_id
# ENSG00000087086  0.934502
# ENSG00000099194  0.907829
# ENSG00000170323  0.964109
# ENSG00000211445  0.945348
# ENSG00000210082  0.921448
# ...                   ...
# ENSG00000225624  0.946207
# ENSG00000231392  0.913184
# ENSG00000284070  0.938569
# ENSG00000237015  0.913782
# ENSG00000235701  0.958785
#
# [28017 rows x 6 columns]

# %%
# Iso_Young_vs_Iso_Old shrink and volcano
shrink_and_volcano_pvalue(Iso_Young_vs_Iso_Old_stat_res, gene_info=gene_info_df,
                   design_factor='condition', 
                   exp_condition='Iso_Young', 
                   ref_condition='Iso_Old', 
                   savedir = Iso_Young_vs_Iso_Old_savedir)
# Out:
# Fitting MAP LFCs...
# Shrunk log2 fold change & Wald test p-value: condition Iso-Young vs Iso-Old
# ... done in 10.27 seconds.
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# gene_id
# ENSG00000087086  936805.272666        3.705117  0.284361  3.922877  0.000087
# ENSG00000099194  462529.560866        3.609337  0.422307  4.439174  0.000009
# ENSG00000170323  403183.355608        3.729774  0.401705  2.648726  0.008080
# ENSG00000211445  201513.436910        0.728878  0.242274  3.411252  0.000647
# ENSG00000210082  155687.858793        3.005248  0.457860  2.902548  0.003701
# ...                        ...             ...       ...       ...       ...
# ENSG00000225624       0.156573       -0.021393  0.458488 -0.165450  0.868590
# ENSG00000231392       0.000000             NaN       NaN       NaN       NaN
# ENSG00000284070       0.277852       -0.025854  0.441541 -0.367405  0.713317
# ENSG00000237015       0.146414        0.021353  0.949256  0.268969  0.787954
# ENSG00000235701       0.336474        0.032790  1.407642  0.666996  0.504775
#
#                      padj
# gene_id
# ENSG00000087086  0.001870
# ENSG00000099194  0.000295
# ENSG00000170323  0.058061
# ENSG00000211445  0.008987
# ENSG00000210082  0.033515
# ...                   ...
# ENSG00000225624       NaN
# ENSG00000231392       NaN
# ENSG00000284070       NaN
# ENSG00000237015       NaN
# ENSG00000235701       NaN
#
# [28017 rows x 6 columns]

# %%
# build savedir for Het_YO vs Het_OY DE results
Het_YO_vs_Het_OY_savedir = deglist_savedir + '4.Het_YO_vs_Het_OY/use_pval/'

# Run DESeqAnalysis_Pipeline to compare Het_YO_vs_Het_OY
Het_YO_vs_Het_OY_stat_res = Prenormed_Paired_DESeq2_Analysis_pvalue(counts_df=counts_df, 
                                                     metadata=metadata, 
                                                     gene_info=gene_info_df,
                                                     size_factors=size_factors,
                                                     design_factor='condition', 
                                                     exp_condition='Het_YO', 
                                                     ref_condition='Het_OY', 
                                                     savedir = Het_YO_vs_Het_OY_savedir)
Het_YO_vs_Het_OY_stat_res
# Out:
# Proceeding to dds object construction
# /Users/skyhe/opt/anaconda3/envs/py310/lib/python3.10/site-packages/pydeseq2/dds.py:257: UserWarning: Some factor levels in the design contain underscores ('_').
#                     They will be converted to hyphens ('-').
#   self.obsm["design_matrix"] = build_design_matrix(
# Fitting dispersions...
# ... done in 9.40 seconds.
#
# Fitting dispersion trend curve...
# ... done in 5.69 seconds.
#
# Fitting MAP dispersions...
# ... done in 8.00 seconds.
#
# Fitting LFCs...
# ... done in 5.65 seconds.
#
# Refitting 0 outliers.
#
# Running Wald tests...
# Log2 fold change & Wald test p-value: cond